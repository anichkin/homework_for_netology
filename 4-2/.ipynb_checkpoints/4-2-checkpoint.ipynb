# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
p = os.path.abspath('C:/4-1/names/yob2004.txt')

# %%
x = pd.read_csv(p, 
            names=['Name', 'Gender', 'Count'])
x[x.Name == 'Ruth']
# Out:
#      Name Gender  Count
# 350  Ruth      F    905

# %%
for file in os.listdir('C:/4-1/names/'):
    path = os.path.abspath('C:/4-1/names/' + file)
    x = pd.read_csv(path, 
            names=['Name', 'Gender', 'Count'])
    ruth = x[x.Name == 'Ruth']
    print(ruth.Count)
# Out:
# 92    234
# Name: Count, dtype: int64
# 83    275
# Name: Count, dtype: int64
# 79    323
# Name: Count, dtype: int64
# 73    387
# Name: Count, dtype: int64
# 73    442
# Name: Count, dtype: int64
# 69      506
# 2272      5
# Name: Count, dtype: int64
# 65    581
# Name: Count, dtype: int64
# 61      627
# 2351      5
# Name: Count, dtype: int64
# 58    850
# Name: Count, dtype: int64
# 45    1073
# Name: Count, dtype: int64
# 45      1195
# 2666       5
# Name: Count, dtype: int64
# 18    1857
# Name: Count, dtype: int64
# 4       3290
# 2292      12
# Name: Count, dtype: int64
# 2       3658
# 2257      12
# Name: Count, dtype: int64
# 5       3372
# 2236      15
# Name: Count, dtype: int64
# 5       3551
# 2773       7
# Name: Count, dtype: int64
# 4       3905
# 2491      12
# Name: Count, dtype: int64
# 4       3878
# 2233      20
# Name: Count, dtype: int64
# 4       4249
# 2541      15
# Name: Count, dtype: int64
# 4       3912
# 2612       9
# Name: Count, dtype: int64
# ...
